# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
from matplotlib.dates import DateFormatter
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
sns.set(font_scale=1.5, style="whitegrid")
file = '/Users/rpsmithii/Desktop/report1601749099727.csv'
df = pd.read_csv(file, sep=',', encoding = "ISO-8859-1")
df = df.rename(columns={'Create Date': 'CDate'})
start = '2018-01-01'
df['CDate'] = pd.to_datetime(df['CDate'], format='%m/%d/%Y')
#df.info()

# %%
leads = df[df.CDate > start]
leads = leads['CDate'].value_counts(dropna = True, sort = True)
leads = pd.DataFrame(leads)
leads = leads.reset_index()
leads.columns = ['Date', 'Leads']

filename = 'ht_leads.png'
title = 'Leads\nby Date limited <= ' + str(ylimit) + ' per day'
ylimit = 15

ax = ind_df.plot(x ='Date', 
                 y ='Leads',
                 rot = 0,
                 legend = False,
                 fontsize = '12',
                 figsize =(16,9),
                 title = title,
                 color = '#008bac')
ax.set_ylim(0, ylimit)
ax.tick_params(axis = 'y',          # changes apply to the x-axis
               which = 'both',      # both major and minor ticks are affected
               bottom = False,      # ticks along the bottom edge are off
               top = False,         # ticks along the top edge are off
               labelbottom = False) 

plt.tight_layout()
# ax.figure.savefig('ht_leads.png', dpi=96)
plt.savefig(filename, dpi=300, 
                      facecolor='w', 
                      edgecolor='w',
                      orientation='portrait',
                      papertype=None, 
                      format='png',
                      transparent=False, 
                      bbox_inches=None, 
                      pad_inches=0.1,
                      frameon=None, 
                      metadata=None)
# Out:
# &lt;Figure size 1152x648 with 1 Axes&gt;
