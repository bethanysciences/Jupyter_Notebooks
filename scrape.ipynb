# %% [markdown]
# Lead Paint Project:
#
# [6K+ MSF 8,153 Venues Search](https://www.cvent.com/venues/results/United%20States?filter=eJyNUktvgkAQ_ivNnjlwaGvijQJaIoIVMNXGkHUZdRseZnepIWb_e2fRxjaNaS_fYWa-x8zuiTzNncgjwxPZU7mgJS-mVLE9SDJUogWLfNCyBTIkxCISSmAKipBLhQytLZLGqRPmU99Pg2icJzPH9Y1WeygoDgY1EiVqgkB6BVS2AiqoVVZzVCDBdObPAyfEJrq7rVRNtTj7bWkp0b3i9YiXCsSl_Gjbdl8lQ_sa6NK86mGyhR9lfp4uZ32gfgvc6Y2krxO0y7Y-4kQMEMevR8Ru1SG-DJaI3kOEuBP3JtjKJWuLNIy1QkDNIO0Oxit5jrPQM05unEXpfJm7sXf1-nmxpN3tQCre1CbDiRQgmeAHU8DBLMHRmlaGZC4DxV2i8H4Sy-rs5jZtrQTHkl7_eohvXSN-Q-krVu_WbN5RwXAFPUb_IBScYmLF2UgA3CCwPkZnVP_OoLVea-vWryu4pJsSEqCC7S-_QetP-QjgSA&geo=eJydkF1rgzAUhv9KOdedVGs_zF2_JsKqZSprGaNkmtaAJiUeR0vxvy_ZqLAVdrGrkHOew_PyXuEgVUURWR4zqrIiYWcEAqngetSLkSKroQ9c_zktfSaPip4Knj3yEpnS5DxKw2UQ-vt5tNXgu2xEzsVxLs835Ap4ObE_UQMJqbBY0Ro3kgs0k5Lqx_Ws4bQPpRRAHsZjy3PbPtSyweKF_WadkTV1bqztuNbQa1uNH7vYX_xdsPVsG6zT9X4ZxMksXKx0uIqeedVUQOy78043nFgDb-C4N6M3sia2M_Vs46R5riuTgpbfuhrIayfcRE87Pwq154OWDTM72DiELHRDyfOOkB_99-ShN6uY4hmFt3_F0VeZFAeeM8OjapgZNALVZSFzkyiNof0ED_OqHA&measurementUnit=IMPERIAL&p=1&sort=CVENT_PICKS&view=LIST)
#
# <h3 class="util__textEllipsis___2q9bM VenueCard__venueName___3G7hn" data-cvent-id="searchResult-mainContent-mainResults-venueListContainer-ul-li-0-venueCard-link-wrapper-venueInfoWrapper-venueName">Astor Crowne Plaza-New Orleans French Quarter</h3>
#
# <span itemprop="addressLocality" data-cvent-id="searchResult-mainContent-mainResults-venueListContainer-ul-li-0-venueCard-link-wrapper-venueInfoWrapper-venueCardDetailsContainer-link-wrapper-venueInfoWrapper-clearfix-floatLeft-divVenueLocation-venueLocation-span-addressAllWrapper-span-addressLocality">New Orleans</span>
#
# <span itemprop="addressRegion" data-cvent-id="searchResult-mainContent-mainResults-venueListContainer-ul-li-0-venueCard-link-wrapper-venueInfoWrapper-venueCardDetailsContainer-link-wrapper-venueInfoWrapper-clearfix-floatLeft-divVenueLocation-venueLocation-span-addressAllWrapper-span-addressRegion">, LA</span>
#
# <div><div>Guest rooms</div><div class="VenueCard__mobileDetails___3Zwn_">693</div></div>
#
# <li class="VenueQuickView__mobileBuildInfo___3F9Za" data-cvent-id="searchResult-mainContent-mainResults-venueListContainer-ul-li-11-venueQuickView-contentWrapper-spacer1-roomInfo-ul-li-0">Chain: IHG</li>
#
# <li class="VenueQuickView__mobileBuildInfo___3F9Za" data-cvent-id="searchResult-mainContent-mainResults-venueListContainer-ul-li-11-venueQuickView-contentWrapper-spacer1-roomInfo-ul-li-1">Brand: Crowne Plaza Hotels</li>
#
# <div class="VenueCard__labels___16efc">Total meeting space</div><div class="VenueCard__mobileDetails___3Zwn_"> 25,000 sq. ft.</div>
#
# <div class="VenueCard__labels___16efc">Largest room</div><div class="VenueCard__mobileDetails___3Zwn_"> 4,070 sq. ft.</div>
#
# <div class="VenueCard__labels___16efc">Meeting rooms</div><div class="VenueCard__mobileDetails___3Zwn_"> 16</div>
#
# <li class="VenueQuickView__mobileBuildInfo___3F9Za" data-cvent-id="searchResult-mainContent-mainResults-venueListContainer-ul-li-11-venueQuickView-contentWrapper-spacer1-roomInfo-ul-li-3">Renovated: 2018</li>
#
# <li class="VenueQuickView__mobileBuildInfo___3F9Za" data-cvent-id="searchResult-mainContent-mainResults-venueListContainer-ul-li-11-venueQuickView-contentWrapper-spacer1-roomInfo-ul-li-4">Distance from airport: 27 mi.</li>
#
# <img data-cvent-id="undefined-canvas-picture-img" class="Image__imageScaleWidthToFit___3AWRg" src="https://d3hfxk7rwdcpol.cloudfront.net/CSN/961bb441-c6bd-4000-a64e-142e51de65ab/images/30ad31ae9d014427bad97713ed8d5bd3_LARGE.jpg" alt="" tabindex="0" role="button" style="visibility: visible;">
#
# <li><a href="#" class="Pagination__link___-CGig Pagination__pageNumber___2aOyj Link__link___3g8zn" title="Next"><span class="Icons-All__container___2fQ8e"><span class="Icons-All__forward___3sLtK Icons-All__icon___2pjL2 Pagination__icon___3doMm" role="img" aria-label="Next"></span></span></a></li>

# %%
# Scrapy
import scrapy
from scrapy.crawler import CrawlerProcess
import json
import logging
import pandas as pd

class JsonWriterPipeline(object):

    def open_spider(self, spider):
        self.file = open('venues.jl', 'w')

    def close_spider(self, spider):
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item
    
class QuotesSpider(scrapy.Spider):
    name = "venues"
    start_urls = ['https://www.cvent.com/venues/results/United%20States?filter=eJyNUktvgkAQ_ivNnjlwaGvijQJaIoIVMNXGkHUZdRseZnepIWb_e2fRxjaNaS_fYWa-x8zuiTzNncgjwxPZU7mgJS-mVLE9SDJUogWLfNCyBTIkxCISSmAKipBLhQytLZLGqRPmU99Pg2icJzPH9Y1WeygoDgY1EiVqgkB6BVS2AiqoVVZzVCDBdObPAyfEJrq7rVRNtTj7bWkp0b3i9YiXCsSl_Gjbdl8lQ_sa6NK86mGyhR9lfp4uZ32gfgvc6Y2krxO0y7Y-4kQMEMevR8Ru1SG-DJaI3kOEuBP3JtjKJWuLNIy1QkDNIO0Oxit5jrPQM05unEXpfJm7sXf1-nmxpN3tQCre1CbDiRQgmeAHU8DBLMHRmlaGZC4DxV2i8H4Sy-rs5jZtrQTHkl7_eohvXSN-Q-krVu_WbN5RwXAFPUb_IBScYmLF2UgA3CCwPkZnVP_OoLVea-vWryu4pJsSEqCC7S-_QetP-QjgSA&geo=eJydkF1rgzAUhv9KOdedVGs_zF2_JsKqZSprGaNkmtaAJiUeR0vxvy_ZqLAVdrGrkHOew_PyXuEgVUURWR4zqrIiYWcEAqngetSLkSKroQ9c_zktfSaPip4Knj3yEpnS5DxKw2UQ-vt5tNXgu2xEzsVxLs835Ap4ObE_UQMJqbBY0Ro3kgs0k5Lqx_Ws4bQPpRRAHsZjy3PbPtSyweKF_WadkTV1bqztuNbQa1uNH7vYX_xdsPVsG6zT9X4ZxMksXKx0uIqeedVUQOy78043nFgDb-C4N6M3sia2M_Vs46R5riuTgpbfuhrIayfcRE87Pwq154OWDTM72DiELHRDyfOOkB_99-ShN6uY4hmFt3_F0VeZFAeeM8OjapgZNALVZSFzkyiNof0ED_OqHA&measurementUnit=IMPERIAL&p=1&sort=CVENT_PICKS&view=LIST']

    custom_settings = {
        'LOG_LEVEL': logging.WARNING,
        'ITEM_PIPELINES': {'__main__.JsonWriterPipeline': 1},       # Used for pipeline 1
        'FEED_FORMAT':'json',                                       # Used for pipeline 2
        'FEED_URI': 'venues.json'                                   # Used for pipeline 2
    }
    
    def parse(self, response):
        for venue in response.css('div.quote'):
            yield {
                'name': quote.css('span.text::text').extract_first(),
                
data-cvent-id="searchResult-mainContent-mainResults-venueListContainer-ul-li-0-venueCard-link-wrapper-venueInfoWrapper-venueName
                
                'author': quote.css('span small::text').extract_first(),
                'tags': quote.css('div.tags a.tag::text').extract(),
            }
        
        NEXT_PAGE_SELECTOR = '.next a ::attr(href)'
        next_page = response.css(NEXT_PAGE_SELECTOR).extract_first()
        if next_page:
            yield scrapy.Request(
                response.urljoin(next_page),
                callback=self.parse
            )

process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})

process.crawl(QuotesSpider)
process.start()
# Out:
#   File "<ipython-input-1-a6ab50ac1ecb>", line 37
#     data-cvent-id="searchResult-mainContent-mainResults-venueListContainer-ul-li-0-venueCard-link-wrapper-venueInfoWrapper-venueName
#                  ^
# SyntaxError: invalid syntax

# %%
# Scrapy
import scrapy
from scrapy.crawler import CrawlerProcess
import json
import logging
import pandas as pd

class JsonWriterPipeline(object):

    def open_spider(self, spider):
        self.file = open('quoteresult.jl', 'w')

    def close_spider(self, spider):
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item
    
class QuotesSpider(scrapy.Spider):
    name = "quotes"
    start_urls = [
        'http://quotes.toscrape.com/page/1/',
        'http://quotes.toscrape.com/page/2/',
    ]
    custom_settings = {
        'LOG_LEVEL': logging.WARNING,
        'ITEM_PIPELINES': {'__main__.JsonWriterPipeline': 1}, # Used for pipeline 1
        'FEED_FORMAT':'json',                                 # Used for pipeline 2
        'FEED_URI': 'quoteresult.json'                        # Used for pipeline 2
    }
    
    def parse(self, response):
        for quote in response.css('div.quote'):
            yield {
                'text': quote.css('span.text::text').extract_first(),
                'author': quote.css('span small::text').extract_first(),
                'tags': quote.css('div.tags a.tag::text').extract(),
            }
        
        NEXT_PAGE_SELECTOR = '.next a ::attr(href)'
        next_page = response.css(NEXT_PAGE_SELECTOR).extract_first()
        if next_page:
            yield scrapy.Request(
                response.urljoin(next_page),
                callback=self.parse
            )

process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})

process.crawl(QuotesSpider)
process.start()
# Out:
# 2019-07-20 19:35:43 [scrapy.utils.log] INFO: Scrapy 1.7.1 started (bot: scrapybot)
# 2019-07-20 19:35:43 [scrapy.utils.log] INFO: Versions: lxml 4.3.4.0, libxml2 2.9.9, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 19.2.1, Python 3.7.3 (default, Jun 19 2019, 07:38:49) - [Clang 10.0.1 (clang-1001.0.46.4)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1c  28 May 2019), cryptography 2.7, Platform Darwin-19.0.0-x86_64-i386-64bit
# 2019-07-20 19:35:43 [scrapy.crawler] INFO: Overridden settings: {'FEED_FORMAT': 'json', 'FEED_URI': 'quoteresult.json', 'LOG_LEVEL': 30, 'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}

# %%
dfjl = pd.read_json('quoteresult.jl', lines=True)
dfjl
# Out:
#                   author                                               tags  \
# 0         Marilyn Monroe  [friends, heartbreak, inspirational, life, lov...
# 1           J.K. Rowling                                 [courage, friends]
# 2        Albert Einstein                           [simplicity, understand]
# 3             Bob Marley                                             [love]
# 4              Dr. Seuss                                          [fantasy]
# 5          Douglas Adams                                 [life, navigation]
# 6        Albert Einstein           [change, deep-thoughts, thinking, world]
# 7           J.K. Rowling                               [abilities, choices]
# 8        Albert Einstein     [inspirational, life, live, miracle, miracles]
# 9            Jane Austen                 [aliteracy, books, classic, humor]
# 10        Marilyn Monroe                       [be-yourself, inspirational]
# ...

# %%
# BS4 Scrape 1 page
import csv
import requests
from bs4 import BeautifulSoup

f = csv.writer(open('/System/Volumes/Data/Users/rpsmithii/Desktop/scrape.csv', 'w'))
f.writerow(['field1', 'field2'])

url = 'https://web.archive.org/web/20121007172955/https://www.nga.gov/collection/anZ1.htm'   # url to scrape

# headers = {                         # set up a nice boy identifier (page = requests.get(url, headers = headers)
#    'User-Agent': 'Your Name, example.com','From': 'email@example.com'
# }

page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')

trash = soup.find(class_='AlphaNav')                # Remove trash tags
trash.decompose()
# print(soup.prettify())                            # pretty print returned text
# soup.find_all('p')                                # return all instances tag
# soup.find_all('p')[2].get_text()                  # return text from third tag container
# soup.find_all(class_='chorus')                    # return text from tag class lable
# soup.find_all('p', class_='chorus')               # return text from tag and class lable

element_list = soup.find(class_='BodyText')         # Pull from BodyText div
element_list_items = element_list.find_all('a')     # Pull from <a> tags from BodyText div

for element in element_list_items:                  # loop out target elements
    field1 = element.contents[0]
    field2 = 'https://web.archive.org' + element.get('href')
    # print(field1, field2)                         # check output
    f.writerow([field1, field2])

# %%
# BS4 Scrape multiple pages
import csv
import requests
from bs4 import BeautifulSoup

f = csv.writer(open('/System/Volumes/Data/Users/rpsmithii/Desktop/scrape.csv', 'w'))
f.writerow(['field1', 'field2'])

pages = []                                         # initialize page counter
pages2get = 5                                       # set pages to scrape (+1 of total)

for i in range(1, pages2get):                       # ingest pages to scrape into array                 
    url = 'https://web.archive.org/web/20121007172955/https://www.nga.gov/collection/anZ' + str(i) + '.htm'
    pages.append(url)
    
for item in pages:
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    
    trash = soup.find(class_='AlphaNav')                # Remove trash tags
    trash.decompose()
    
    element_list = soup.find(class_='BodyText')         # Pull from BodyText div
    element_list_items = element_list.find_all('a')     # Pull from <a> tags from BodyText div
    
    for element in element_list_items:                  # loop out target elements
        field1 = element.contents[0]
        field2 = 'https://web.archive.org' + element.get('href')
        print(field1, field2)                         # check output
        f.writerow([field1, field2])
# Out:
# Zorzo da Castelfranco https://web.archive.org/web/20121010201041/http://www.nga.gov/cgi-bin/tsearch?artistid=1341
# Zox, Larry https://web.archive.org/web/20121010201041/http://www.nga.gov/cgi-bin/tsearch?artistid=6731
# Zsissly https://web.archive.org/web/20121010201041/http://www.nga.gov/cgi-bin/tsearch?artistid=6496
# Zuccarelli, Francesco https://web.archive.org/web/20121010201041/http://www.nga.gov/cgi-bin/tsearch?artistid=6350
# Zuccarello, Anthony https://web.archive.org/web/20121010201041/http://www.nga.gov/cgi-bin/tsearch?artistid=8237
# Zuccari, Federico https://web.archive.org/web/20121010201041/http://www.nga.gov/cgi-bin/tsearch?artistid=2812
# Zuccari, Taddeo https://web.archive.org/web/20121010201041/http://www.nga.gov/cgi-bin/tsearch?artistid=2813
# Zuccaro, Federico https://web.archive.org/web/20121010201041/http://www.nga.gov/cgi-bin/tsearch?artistid=2812
# Zuccaro, Federigo https://web.archive.org/web/20121010201041/http://www.nga.gov/cgi-bin/tsearch?artistid=2812
# ...

# %% [markdown]
# ## Avoiding Entanglements
# - rotate your user agent from a pool of well-known ones from browsers (google around to get a list of them)
# - disable cookies (see COOKIES_ENABLED) as some sites may use cookies to spot bot behaviour
# - use download delays (2 or higher). See DOWNLOAD_DELAY setting.
# - if possible, use Google cache to fetch pages, instead of hitting the sites directly
# - use a pool of rotating IPs. For example, the free Tor project or paid services like ProxyMesh. An open source alternative is scrapoxy, a super proxy that you can attach your own proxies to.
# - use a highly distributed downloader that circumvents bans internally, so you can just focus on parsing clean pages. One example of such downloaders is Crawlera
